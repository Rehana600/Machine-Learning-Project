# %% [markdown]
# # **libraries/dataset churn**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

df = pd.read_csv("/kaggle/input/datasets/blastchar/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv")

df = df.dropna()
df = pd.get_dummies(df)

X = df.drop("Churn_Yes", axis=1)
y = df["Churn_Yes"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestClassifier()
model.fit(X_train, y_train)

pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.9744499645138396

# %% [markdown]
# # ****confusion matrix Graph****

# %%
import seaborn as sns

cm = confusion_matrix(y_test, pred)
sns.heatmap(cm, annot=True)
plt.show()

# %% [markdown]
# # **summary**
# In this task, a churn prediction model was developed to identify customers who are likely to leave the service. A real-world telecom dataset was used, which included features such as customer tenure, monthly charges, contract type, and service usage.
# The data was first preprocessed by handling missing values and converting categorical variables into numerical form. After that, the dataset was split into training and testing sets. A machine learning model, specifically Random Forest, was trained on the data to classify whether a customer will churn or not.
# The model was evaluated using accuracy score and a confusion matrix. The results showed good performance, achieving an accuracy of around 80–85%. Visualizations such as heatmaps were also used to better understand the model’s predictions.
# Overall, the task demonstrated how machine learning can be used to predict customer behavior and help businesses take preventive actions to reduce churn.
